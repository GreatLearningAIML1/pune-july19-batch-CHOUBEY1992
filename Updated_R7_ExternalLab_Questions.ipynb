# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
# %tensorflow_version 2.x
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
tf.__version__
# Out:
# '2.1.0-rc1'

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
#Convert labels to one hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %%
#x_test_norm = tf.keras.backend.expand_dims(x_test,3)
#x_train_norm = tf.keras.backend.expand_dims(x_train,3)

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000, 10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
tf.keras.backend.clear_session()
#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))

# %%
#normalize data
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Dense layer
model.add(tf.keras.layers.Dense(200, activation='relu'))
#Dense layer
model.add(tf.keras.layers.Dense(100, activation='relu'))

#adding dropout layers
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 784)               0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 784)               3136
# _________________________________________________________________
# dense (Dense)                (None, 200)               157000
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 181,246
# Trainable params: 179,678
# Non-trainable params: 1,568
# _________________________________________________________________

# %%
#Train the model
model.fit(x_train,y_train,          
          validation_data=(x_test,y_test),
          epochs=10,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 11s 180us/sample - loss: 0.5146 - accuracy: 0.8168 - val_loss: 0.4236 - val_accuracy: 0.8454
# Epoch 2/10
# 60000/60000 [==============================] - 10s 162us/sample - loss: 0.3958 - accuracy: 0.8560 - val_loss: 0.3676 - val_accuracy: 0.8650
# Epoch 3/10
# 60000/60000 [==============================] - 10s 160us/sample - loss: 0.3619 - accuracy: 0.8677 - val_loss: 0.3661 - val_accuracy: 0.8682
# Epoch 4/10
# 60000/60000 [==============================] - 10s 168us/sample - loss: 0.3354 - accuracy: 0.8760 - val_loss: 0.3534 - val_accuracy: 0.8720
# Epoch 5/10
# 60000/60000 [==============================] - 10s 172us/sample - loss: 0.3143 - accuracy: 0.8851 - val_loss: 0.3595 - val_accuracy: 0.8736
# Epoch 6/10
# 60000/60000 [==============================] - 10s 163us/sample - loss: 0.3003 - accuracy: 0.8888 - val_loss: 0.3403 - val_accuracy: 0.8804
# Epoch 7/10
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.2870 - accuracy: 0.8927 - val_loss: 0.3469 - val_accuracy: 0.8807
# Epoch 8/10
# 60000/60000 [==============================] - 9s 156us/sample - loss: 0.2750 - accuracy: 0.8986 - val_loss: 0.3459 - val_accuracy: 0.8879
# Epoch 9/10
# 60000/60000 [==============================] - 9s 154us/sample - loss: 0.2618 - accuracy: 0.9014 - val_loss: 0.3621 - val_accuracy: 0.8853
# Epoch 10/10
# 60000/60000 [==============================] - 9s 155us/sample - loss: 0.2565 - accuracy: 0.9028 - val_loss: 0.3490 - val_accuracy: 0.8877

# %%
print("final accuracy is 0.8877")
# Out:
# final accuracy is 0.8877
